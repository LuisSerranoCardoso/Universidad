# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisSerranoCardoso/Universidad/blob/main/Clase15Sept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Clase del 16 de septiembre**

# %% [markdown]
# Probar Docstring

# %%
def greet(name):
    """
    This function greets the person whose name is passed as an argument.
    Parameters:
        name (str): The name of the person to greet.
    Returns:
None
    """
    print("Hola       " + name + "!")
# Using the help function to access the docstring
help(greet)
print(greet.__doc__)
# Out:
# Help on function greet in module __main__:
#
# greet(name)
#         This function greets the person whose name is passed as an argument.
#         Parameters:
#             name (str): The name of the person to greet.
#         Returns:
#     None
#
#
#     This function greets the person whose name is passed as an argument.
#     Parameters:
#         name (str): The name of the person to greet.
#     Returns:
# None

# %% [markdown]
# Control flow

# %%
x=4
y=5
it_is_tuesday = True
# this function definition starts a new block
def print_numbers(a, b):
    # this instruction is inside the block
    print("Numbers are:", a, b)
# this if statement starts a new block
if it_is_tuesday:
    # this is inside the block
    print("It's Tuesday!")
# this is outside the block!
print("Print this no matter what")
print_numbers(x,y)
# Out:
# It's Tuesday!
# Print this no matter what
# Numbers are: 4 5

# %% [markdown]
# Ejemplo Indentación

# %%
def happy_day(day):
  if day == "monday":
    return ":("
  if day != "monday":
    return ":D"

print(happy_day("sunday"))
print(happy_day("monday"))
# Out:
# :D
# :(

# %% [markdown]
# Tipos predefinidos

# %%
print(type(109))     # <class 'int'>
print(type("a"))   # <class 'str’>
print(type(2.45))  # <class 'float’>
print(type(True))  # <class bool’>
print(type(4 + 4j))#<class 'complex’>
print(type(x))     #<class 'NoneType’>
print(type('c'))   # <class ‘str’>
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Conversión Cast

# %%
#convertir a int()
print("jkjk")
numdec = 5.98
numint = int(numdec)
print(numint)
#convertir de string a int
tex = "45"
numint = int(tex)
print(numint)
#convertir de int a string
numint = 45
tex = str(numint)
print(tex)
#float a string
numdec = 5.98
tex = str(numdec)
print(tex)
#
# Out:
#   File "<ipython-input-1-1cb9025c3063>", line 2
#     print("jkjk)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# operaciones con int and float

# %%
a = int(input("Number: "))
b = float(input("Number: "))
d = a * b /2
d += 1
C = d ** 2
print("Result c y d", C, d)
# Out:
# Number: 2
# Number: 6
# Result c y d 49.0 7.0

# %% [markdown]
# Ejercicio con strings

# %%
message = "File path: C:\\Users\\Username\\Documents\n"
message += "Quote: \"Stay hungry, stay foolish.\" - Steve Jobs\n"
message += "List:\n\t1. Item One\n\t2. Item Two\n\t3. Item Three"
print(message)

# %%
s = 'Marien'
class ejemplo:
  def __init__(self, name):
    self.name = name

print(type(s)) #<class ‘str’>
print(type(str)) #<class ‘type’>
print(type(ejemplo))  #<class ‘type’>
dir(object)

class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p = Person("John", 36)

print(p.name)
print(p.age)
# Out:
# <class 'str'>
# <class 'type'>
# <class 'type'>
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
def outer_function():
    x = 10  # Variable in the enclosing scope
    def inner_function():
        nonlocal x += 5
        print(f"Inside inner_function: {x}")  # 5
    inner_function()
    print(f"Inside outer_function: {x}")  # 10
outer_function()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-1975870994.py in <cell line: 0>()
#       6     inner_function()
#       7     print(f"Inside outer_function: {x}")  # 10
# ----> 8 outer_function()
#
# /tmp/ipython-input-1975870994.py in outer_function()
#       4         x += 5
#       5         print(f"Inside inner_function: {x}")  # 5
# ----> 6     inner_function()
#       7     print(f"Inside outer_function: {x}")  # 10
#       8 outer_function()
#
# /tmp/ipython-input-1975870994.py in inner_function()
#       2     x = 10  # Variable in the enclosing scope
#       3     def inner_function():
# ----> 4         x += 5
#       5         print(f"Inside inner_function: {x}")  # 5
#       6     inner_function()
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value
